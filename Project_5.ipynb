# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishaamalik/Climate-Change-Prediction/blob/main/Project_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Climate Change Prediction

# %% [markdown]
# ## Loading the Dataset

# %%
import pandas as pd
import numpy as np

# %%
file_path = 'climate_change_dataset.csv'
df = pd.read_csv(file_path)

df.head()
# Out:
#    Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0  2006         UK                   8.9                          9.3
# 1  2019        USA                  31.0                          4.8
# 2  2014     France                  33.9                          2.8
# 3  2010  Argentina                   5.9                          1.8
# 4  2007    Germany                  26.9                          5.6
#
#    Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 0                  3.1           1441   530911230                  20.4
# 1                  4.2           2407   107364344                  49.2
# 2                  2.2           1241   441101758                  33.3
# 3                  3.2           1892  1069669579                  23.7
# 4                  2.4           1743   124079175                  12.5
#
#    Extreme Weather Events  Forest Area (%)
# 0                      14             59.8
# 1                       8             31.0
# 2                       9             35.5
# 3                       7             17.7
# 4                       4             17.4

# %% [markdown]
# ----

# %% [markdown]
# #  Data Cleaning & Preprocessing

# %% [markdown]
# ## 1:  Loadind and Basic Inspection

# %%
print("Shape:", df.shape)

df.info()

print("\nMissing values:\n", df.isnull().sum())

df.describe()
# Out:
# Shape: (1000, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         1000 non-null   int64
#  1   Country                      1000 non-null   object
#  2   Avg Temperature (°C)         1000 non-null   float64
#  3   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  4   Sea Level Rise (mm)          1000 non-null   float64
#  5   Rainfall (mm)                1000 non-null   int64
#  6   Population                   1000 non-null   int64
#  7   Renewable Energy (%)         1000 non-null   float64
#  8   Extreme Weather Events       1000 non-null   int64
#  9   Forest Area (%)              1000 non-null   float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 78.3+ KB
#
# Missing values:
#  Year                           0
# Country                        0
# Avg Temperature (°C)           0
# CO2 Emissions (Tons/Capita)    0
# Sea Level Rise (mm)            0
# Rainfall (mm)                  0
# Population                     0
# Renewable Energy (%)           0
# Extreme Weather Events         0
# Forest Area (%)                0
# dtype: int64
#               Year  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# count  1000.000000           1000.000000                  1000.000000
# mean   2011.432000             19.883100                    10.425800
# std       7.147199              8.542897                     5.614665
# min    2000.000000              5.000000                     0.500000
# 25%    2005.000000             12.175000                     5.575000
# 50%    2012.000000             20.100000                    10.700000
# 75%    2018.000000             27.225000                    15.400000
# max    2023.000000             34.900000                    20.000000
#
#        Sea Level Rise (mm)  Rainfall (mm)    Population  Renewable Energy (%)  \
# count          1000.000000    1000.000000  1.000000e+03           1000.000000
# mean              3.009600    1738.761000  7.053830e+08             27.300500
# std               1.146081     708.976616  4.093910e+08             12.970808
# min               1.000000     501.000000  3.660891e+06              5.100000
# 25%               2.000000    1098.750000  3.436242e+08             16.100000
# 50%               3.000000    1726.000000  7.131166e+08             27.150000
# 75%               4.000000    2362.500000  1.073868e+09             38.925000
# max               5.000000    2999.000000  1.397016e+09             50.000000
#
#        Extreme Weather Events  Forest Area (%)
# count             1000.000000      1000.000000
# mean                 7.291000        40.572000
# std                  4.422655        17.398998
# min                  0.000000        10.100000
# 25%                  3.000000        25.600000
# 50%                  8.000000        41.150000
# 75%                 11.000000        55.800000
# max                 14.000000        70.000000

# %% [markdown]
# ## 2: Data Cleaning

# %% [markdown]
# ### 2.1: Check for Missing Values

# %%
missing = df.isnull().sum()
missing_percent = (missing / len(df)) * 100
missing_df = pd.DataFrame({'Missing Values': missing, 'Percent (%)': missing_percent})
missing_df[missing_df['Missing Values'] > 0]
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percent (%)]
# Index: []

# %% [markdown]
# There is no missing value

# %%
for col in df.columns:
    if df[col].dtype in ['float64', 'int64']:
        df[col] = df[col].fillna(df[col].median())
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# ### 2.2: Handle Duplicates

# %%
print("Duplicates:", df.duplicated().sum())

df = df.drop_duplicates()
# Out:
# Duplicates: 0

# %% [markdown]
# Theere is also no duplicate value

# %% [markdown]
# ### 2.3: Check Data Types

# %%
df.dtypes
# Out:
# Year                             int64
# Country                         object
# Avg Temperature (°C)           float64
# CO2 Emissions (Tons/Capita)    float64
# Sea Level Rise (mm)            float64
# Rainfall (mm)                    int64
# Population                       int64
# Renewable Energy (%)           float64
# Extreme Weather Events           int64
# Forest Area (%)                float64
# dtype: object

# %% [markdown]
# All listed data types are appropriate for the respective columns.

# %% [markdown]
# ## 3: Feature Engineering & Encoding

# %% [markdown]
# ### 3.1: Encode Categorical Variables

# %% [markdown]
# Check which are categorical:

# %%
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols].nunique()
# Out:
# Country    15
# dtype: int64

# %% [markdown]
# Apply encoding:

# %%
# Using one-hot encoding for nominal variables
df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %% [markdown]
# ### 3.2: Normalize/Scale Numeric Data

# %%
from sklearn.preprocessing import StandardScaler

num_cols = df.select_dtypes(include=['float64', 'int64']).columns

scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %% [markdown]
# ## 4: Final Check

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         1000 non-null   float64
#  1   Avg Temperature (°C)         1000 non-null   float64
#  2   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  3   Sea Level Rise (mm)          1000 non-null   float64
#  4   Rainfall (mm)                1000 non-null   float64
#  5   Population                   1000 non-null   float64
#  6   Renewable Energy (%)         1000 non-null   float64
#  7   Extreme Weather Events       1000 non-null   float64
#  8   Forest Area (%)              1000 non-null   float64
#  9   Country_Australia            1000 non-null   bool
#  10  Country_Brazil               1000 non-null   bool
#  11  Country_Canada               1000 non-null   bool
#  12  Country_China                1000 non-null   bool
#  13  Country_France               1000 non-null   bool
#  14  Country_Germany              1000 non-null   bool
#  15  Country_India                1000 non-null   bool
#  16  Country_Indonesia            1000 non-null   bool
#  17  Country_Japan                1000 non-null   bool
#  18  Country_Mexico               1000 non-null   bool
#  19  Country_Russia               1000 non-null   bool
#  20  Country_South Africa         1000 non-null   bool
#  21  Country_UK                   1000 non-null   bool
#  22  Country_USA                  1000 non-null   bool
# dtypes: bool(14), float64(9)
# memory usage: 84.1 KB
#        Year  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0 -0.760398             -1.286284                    -0.200611
# 1  1.059406              1.301954                    -1.002485
# 2  0.359481              1.641588                    -1.358873
# 3 -0.200458             -1.637629                    -1.537067
# 4 -0.620413              0.821783                    -0.859929
#
#    Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 0             0.078917      -0.420197   -0.426387             -0.532269
# 1             1.039190       0.943012   -1.461483              1.689213
# 2            -0.706761      -0.702435   -0.645870              0.462770
# 3             0.166215       0.216249    0.890271             -0.277724
# 4            -0.532166       0.005982   -1.420634             -1.141633
#
#    Extreme Weather Events  Forest Area (%)  Country_Australia  ...  \
# 0                1.517721         1.105674              False  ...
# 1                0.160391        -0.550422              False  ...
# 2                0.386613        -0.291657              False  ...
# 3               -0.065831        -1.315216              False  ...
# 4               -0.744495        -1.332467              False  ...
#
#    Country_France  Country_Germany  Country_India  Country_Indonesia  \
# 0           False            False          False              False
# 1           False            False          False              False
# 2            True            False          False              False
# 3           False            False          False              False
# 4           False             True          False              False
#
#    Country_Japan  Country_Mexico  Country_Russia  Country_South Africa  \
# 0          False           False           False                 False
# 1          False           False           False                 False
# 2          False           False           False                 False
# 3          False           False           False                 False
# 4          False           False           False                 False
#
#    Country_UK  Country_USA
# 0        True        False
# 1       False         True
# 2       False        False
# 3       False        False
# 4       False        False
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 5: Downloading the clead dataset

# %%
cleaned_file_path = '/content/cleaned_climate_change_dataset.csv'
df.to_csv(cleaned_file_path, index=False)

# %%
from google.colab import files
files.download(cleaned_file_path)
